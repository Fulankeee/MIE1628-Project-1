fig = go.Figure()

# Colors for clusters
colors = [
    "red", "blue", "green", "purple", "orange",
    "cyan", "magenta", "yellow", "black"
]

# Add scatter plots for each cluster
for cluster_id, points in clusters.items():
    if points:  # Only plot clusters with data
        x, y = zip(*points)
        fig.add_trace(go.Scatter(
            x=x,
            y=y,
            mode="markers",
            name=f"Cluster {cluster_id}",
            marker=dict(size=8, color=colors[cluster_id % len(colors)])
        ))

# Update layout for better visualization
fig.update_layout(
    title="Visualization of 9 Clusters",
    xaxis_title="X Coordinate",
    yaxis_title="Y Coordinate",
    legend_title="Clusters",
    template="plotly_white"
)

# Show plot
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# Load data points from file
data_points = np.loadtxt(r"C:\Frank\UoT 2024-2025\MIE1628\A1\data_points.txt", delimiter=',')

# Cluster centers
cluster_centers = [
(10.22758126453824, 19.249362344724915),  # Cluster 0
(10.757719849294862, 12.642038393010221),  # Cluster 1
(13.602384402550223, -1.0438627930119884),  # Cluster 2
(35.38114898231048, -3.975719462592217),  # Cluster 3
(2.9281401364430963, 9.924340282984303),  # Cluster 4
(50.052102432330464, 30.16555939936289),  # Cluster 5
(35.14277039829759, 4.397049141728923),  # Cluster 6
(-9.759546304082713, -15.266576121798426),  # Cluster 7
(36.149627688787064, 2.5941292390220427)  # Cluster 8
]

# Use KMeans to assign each data point to the closest cluster center
kmeans = KMeans(n_clusters=len(cluster_centers), init=np.array(cluster_centers), n_init=1, max_iter=1)
kmeans.fit(data_points)
labels = kmeans.labels_

# Assign colors to clusters
cluster_colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown', 'pink', 'cyan', 'yellow']
data_colors = [cluster_colors[label] for label in labels]

# Extract x and y coordinates for cluster centers
x_centers, y_centers = zip(*cluster_centers)

# Extract x and y coordinates for data points
x_data, y_data = data_points[:, 0], data_points[:, 1]

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, color=data_colors, marker='.', alpha=0.5, label='Data Points')

# Plot each cluster center with a different color
for i, (x, y) in enumerate(cluster_centers):
    plt.scatter(x, y, color=cluster_colors[i], marker='o', s=100, edgecolor='black', label=f'Cluster {i+1}')

# Labels and title
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Scatter Plot of Data Points and 9-Mean Cluster Centers with Cluster Assignments')
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# C:\Users\frank\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# Load data points from file
data_points = np.loadtxt(r"C:\Frank\UoT 2024-2025\MIE1628\A1\data_points.txt", delimiter=',')

# Cluster centers for 5-mean clustering
cluster_centers = [
    (9.85979681991319, 9.587567430380343),
    (49.98449369373368, 27.39864896951781),
    (49.96208719177415, 35.84016196448722),
    (35.0445724870116, 1.7274566684740302),
    (10.093900706124334, 17.824566263357664)
]

# Use KMeans to assign each data point to the closest cluster center
kmeans = KMeans(n_clusters=len(cluster_centers), init=np.array(cluster_centers), n_init=1, max_iter=1)
kmeans.fit(data_points)
labels = kmeans.labels_

# Assign colors to clusters
cluster_colors = ['red', 'green', 'blue', 'orange', 'purple']
data_colors = [cluster_colors[label] for label in labels]

# Extract x and y coordinates for cluster centers
x_centers, y_centers = zip(*cluster_centers)

# Extract x and y coordinates for data points
x_data, y_data = data_points[:, 0], data_points[:, 1]

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, color=data_colors, marker='.', alpha=0.5, label='Data Points')

# Plot each cluster center with a different color
for i, (x, y) in enumerate(cluster_centers):
    plt.scatter(x, y, color=cluster_colors[i], marker='o', s=100, edgecolor='black', label=f'Cluster {i+1}')

# Labels and title
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Scatter Plot of Data Points and 5-Mean Cluster Centers with Cluster Assignments')
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# C:\Users\frank\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define centroids for each iteration
iterations = list(range(1, 19))
centroids = {
    0: [(-21.178, -9.010), (-5.999, 2.114), (0.861, 3.637), (5.037, 4.050), (7.374, 5.017),
        (8.594, 5.995), (9.217, 6.813), (9.528, 7.455), (9.675, 7.955), (9.753, 8.335),
        (9.791, 8.631), (9.815, 8.863), (9.828, 9.051), (9.835, 9.202), (9.846, 9.323),
        (9.852, 9.426), (9.855, 9.512), (9.859, 9.587)],

    1: [(49.078, 28.238), (50.015, 29.602), (50.176, 29.863), (50.263, 29.843), (50.344, 29.749),
        (50.421, 29.558), (50.453, 29.234), (50.388, 28.844), (50.268, 28.498), (50.156, 28.227),
        (50.079, 28.024), (50.032, 27.865), (50.007, 27.739), (49.995, 27.639), (49.990, 27.560),
        (49.986, 27.495), (49.985, 27.441), (49.984, 27.398)],

    2: [(28.097, 50.100), (28.773, 42.521), (31.385, 40.081), (34.326, 38.839), (37.690, 38.757),
        (41.268, 39.243), (44.555, 39.504), (46.995, 39.199), (48.477, 38.541), (49.264, 37.876),
        (49.647, 37.335), (49.829, 36.917), (49.907, 36.600), (49.939, 36.363), (49.951, 36.184),
        (49.959, 36.042), (49.961, 35.929), (49.962, 35.840)],

    3: [(35.067, -7.056), (35.381, 0.608), (35.081, 1.690), (35.051, 1.783), (35.078, 1.799),
        (35.093, 1.805), (35.099, 1.805), (35.095, 1.795), (35.087, 1.780), (35.077, 1.765),
        (35.070, 1.756), (35.064, 1.748), (35.058, 1.742), (35.054, 1.737), (35.051, 1.734),
        (35.048, 1.731), (35.046, 1.729), (35.044, 1.727)],

    4: [(20.467, 9.665), (12.317, 14.337), (10.301, 15.255), (10.260, 15.694), (10.240, 16.106),
        (10.195, 16.454), (10.159, 16.735), (10.134, 16.955), (10.118, 17.132), (10.107, 17.275),
        (10.102, 17.390), (10.098, 17.487), (10.096, 17.569), (10.096, 17.636), (10.094, 17.693),
        (10.093, 17.743), (10.094, 17.786), (10.093, 17.824)]
}

# Plot the centroid movements
plt.figure(figsize=(10, 6))

colors = ['r', 'g', 'b', 'c', 'm']
for cluster, points in centroids.items():
    x, y = zip(*points)
    plt.plot(x, y, marker='o', linestyle='-', color=colors[cluster], label=f'Cluster {cluster}')

plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.title("Centroid Movements Across Iterations")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
